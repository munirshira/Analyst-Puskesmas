# %%
#Upload File
from google.colab import files
# !rm MM.xlsx
files.upload()
# Out:
# rm: cannot remove 'MM.xlsx': No such file or directory
#      <input type="file" id="files-aec28b6d-ed28-4de1-a4c0-3c501e28f94f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aec28b6d-ed28-4de1-a4c0-3c501e28f94f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import os, sys, numpy as np
import matplotlib.pyplot as plt
import numpy.random as rnd

# %%
org_data = pd.read_excel('MM.xlsx')

org_data
# Out:
#     No  Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0    0             0.769231          0.000000
# 1    1             0.615385          0.333333
# 2    2             0.153846          0.333333
# 3    3             0.000000          0.000000
# 4    4             0.461538          0.000000
# 5    5             0.000000          0.000000
# 6    6             0.615385          0.000000
# 7    7             1.000000          0.000000
# 8    8             0.000000          0.000000
# 9    9             0.307692          0.000000
# 10  10             0.153846          0.000000
# 11  11             0.769231          0.000000
# 12  12             0.769231          0.666667
# 13  13             0.000000          0.333333
# 14  14             0.076923          0.000000
# 15  15             0.000000          0.000000
# 16  16             0.307692          0.000000
# 17  17             0.230769          0.000000
# 18  18             0.461538          0.000000
# ...

# %%
org_data = org_data.iloc[:,1:]

# %%
org_data
# Out:
#     Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0              0.769231          0.000000
# 1              0.615385          0.333333
# 2              0.153846          0.333333
# 3              0.000000          0.000000
# 4              0.461538          0.000000
# 5              0.000000          0.000000
# 6              0.615385          0.000000
# 7              1.000000          0.000000
# 8              0.000000          0.000000
# 9              0.307692          0.000000
# 10             0.153846          0.000000
# 11             0.769231          0.000000
# 12             0.769231          0.666667
# 13             0.000000          0.333333
# 14             0.076923          0.000000
# 15             0.000000          0.000000
# 16             0.307692          0.000000
# 17             0.230769          0.000000
# 18             0.461538          0.000000
# 19             0.000000          0.333333
# 20             0.153846          0.333333
# ...

# %% [markdown]
# ## 3. Mean centering

# %%
# Subtract mean from data
mean = np.mean(org_data, axis= 0)
print("Mean ", mean.shape)
mean_data = org_data - mean
print("Data after subtracting mean ", org_data.shape, "\n")
# Out:
# Mean  (14,)
# Data after subtracting mean  (36, 14)

# %%
mean
# Out:
# Jumlah_Tempat_Tidur                                0.329060
# Jumlah_Ambulance                                   0.138889
# Jumlah_Puskesmas_Keliling_Roda_Empat               0.398148
# Jumlah_Puskesmas_Pembantu                          0.229167
# Jumlah_Dokter_Umum                                 0.458333
# Jumlah_Dokter_Gigi                                 0.055556
# Jumlah_Perawat                                     0.341880
# Jumlah_Bidan                                       0.344444
# Jumlah_Farmasi                                     0.611111
# Jumlah_Kesehatan_Masyarakat                        0.481481
# Jumlah_Kesehatan_Lingkungan                        0.027778
# Jumlah_Tenaga_Gizi                                 0.638889
# Jumlah_Tenaga_Ahli_Teknologi_Laboratorium_Medik    0.787037
# Jumlah_Tenaga_Non_Medis                            0.569444
# dtype: float64

# %%
mean_data
# Out:
#     Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0              0.440171         -0.138889
# 1              0.286325          0.194444
# 2             -0.175214          0.194444
# 3             -0.329060         -0.138889
# 4              0.132478         -0.138889
# 5             -0.329060         -0.138889
# 6              0.286325         -0.138889
# 7              0.670940         -0.138889
# 8             -0.329060         -0.138889
# 9             -0.021368         -0.138889
# 10            -0.175214         -0.138889
# 11             0.440171         -0.138889
# 12             0.440171          0.527778
# 13            -0.329060          0.194444
# 14            -0.252137         -0.138889
# 15            -0.329060         -0.138889
# 16            -0.021368         -0.138889
# 17            -0.098291         -0.138889
# 18             0.132478         -0.138889
# 19            -0.329060          0.194444
# 20            -0.175214          0.194444
# ...

# %%
t = mean_data.T
kali = t.dot(mean_data)
kali = kali * (1/35)
kali.shape
kali
# Out:
#                                                  Jumlah_Tempat_Tidur  \
# Jumlah_Tempat_Tidur                                         0.085752
# Jumlah_Ambulance                                            0.008669
# Jumlah_Puskesmas_Keliling_Roda_Empat                       -0.008018
# Jumlah_Puskesmas_Pembantu                                   0.002106
# Jumlah_Dokter_Umum                                          0.015751
# Jumlah_Dokter_Gigi                                         -0.005617
# Jumlah_Perawat                                              0.028496
# Jumlah_Bidan                                                0.043858
# Jumlah_Farmasi                                             -0.020024
# Jumlah_Kesehatan_Masyarakat                                -0.032560
# Jumlah_Kesehatan_Lingkungan                                 0.012576
# Jumlah_Tenaga_Gizi                                          0.016728
# Jumlah_Tenaga_Ahli_Teknologi_Laboratorium_Medik             0.019332
# ...

# %% [markdown]
# ## 4. Compute covariance matrix

# %%
# Compute covariance matrix
cov = np.cov(mean_data.T)
print("Covariance matrix ", cov.shape, "\n")
# Out:
# Covariance matrix  (14, 14)

# %%
cov
# Out:
# array([[ 0.0857519 ,  0.00866913, -0.00801791,  0.00210624,  0.01575093,
#         -0.00561662,  0.02849633,  0.0438584 , -0.02002444, -0.03256008,
#          0.01257632,  0.01672772,  0.0193325 ,  0.00921857],
#        [ 0.00866913,  0.05317458,  0.00978836,  0.00773809, -0.00119047,
#         -0.0079365 ,  0.02002443,  0.01174602, -0.0047619 , -0.03068783,
#         -0.00396825,  0.00396824,  0.01137565,  0.00542328],
#        [-0.00801791,  0.00978836,  0.05599655,  0.00376984,  0.00992064,
#          0.00582011,  0.01017502,  0.00846561,  0.00052912,  0.00282188,
#         -0.01137566, -0.01402118,  0.00784833,  0.02447094],
#        [ 0.00210624,  0.00773809,  0.00376984,  0.07276786,  0.03125   ,
#         -0.00595238,  0.03150186,  0.04809524,  0.02261904,  0.00317462,
#          0.0077381 ,  0.0422619 ,  0.02400793,  0.02529761],
#        [ 0.01575093, -0.00119047,  0.00992064,  0.03125   ,  0.05178571,
# ...

# %%
covpd = pd.DataFrame(cov)

# %%
covpd
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.085752  0.008669 -0.008018  0.002106  0.015751 -0.005617  0.028496
# 1   0.008669  0.053175  0.009788  0.007738 -0.001190 -0.007937  0.020024
# 2  -0.008018  0.009788  0.055997  0.003770  0.009921  0.005820  0.010175
# 3   0.002106  0.007738  0.003770  0.072768  0.031250 -0.005952  0.031502
# 4   0.015751 -0.001190  0.009921  0.031250  0.051786 -0.004762  0.029487
# 5  -0.005617 -0.007937  0.005820 -0.005952 -0.004762  0.053968 -0.010745
# 6   0.028496  0.020024  0.010175  0.031502  0.029487 -0.010745  0.042078
# 7   0.043858  0.011746  0.008466  0.048095  0.043333 -0.013968  0.038217
# 8  -0.020024 -0.004762  0.000529  0.022619  0.007143  0.003175  0.007082
# 9  -0.032560 -0.030688  0.002822  0.003175  0.013492  0.020106 -0.013268
# 10  0.012576 -0.003968 -0.011376  0.007738 -0.005952 -0.001587  0.003419
# 11  0.016728  0.003968 -0.014021  0.042262  0.027381  0.020635  0.003907
# ...

# %% [markdown]
# ## 5. Perform eigen decomposition of covariance matrix

# %%
# Perform eigen decomposition of covariance matrix
eig_val, eig_vec = np.linalg.eig(cov)
print("Eigen vectors ", eig_vec.shape)
print("Eigen values ", eig_val.shape, "\n")
# Out:
# Eigen vectors  (14, 14)
# Eigen values  (14,)

# %%
eig_val_pd = pd.DataFrame(eig_val)
eig_val_pd
# Out:
#            0
# 0   0.318652
# 1   0.230506
# 2   0.136693
# 3   0.089117
# 4   0.073741
# 5   0.004895
# 6   0.012303
# 7   0.014929
# 8   0.018428
# 9   0.026463
# 10  0.035193
# 11  0.044448
# 12  0.046077
# 13  0.065778

# %%
eig_vec_pd = pd.DataFrame(eig_vec)
eig_vec_pd
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.194196 -0.278340 -0.363651  0.167952  0.588539 -0.217195 -0.320139
# 1  -0.064367 -0.183941 -0.119349 -0.117707 -0.405482 -0.271900  0.156659
# 2  -0.015154 -0.106519  0.285048 -0.244867 -0.011624 -0.107538 -0.094836
# 3  -0.310017 -0.098611  0.286744  0.149338 -0.341622 -0.189915 -0.423548
# 4  -0.253655 -0.105037  0.253145  0.165013  0.199158 -0.349947  0.545111
# 5   0.006819  0.218472 -0.036368  0.061543  0.065265  0.061030  0.114409
# 6  -0.192230 -0.254291  0.129228  0.134606  0.021711  0.795488  0.151462
# 7  -0.435900 -0.283847 -0.000141  0.374636 -0.008834  0.079427  0.116242
# 8  -0.034361  0.076154  0.340373  0.331116 -0.302384 -0.087427 -0.020626
# 9  -0.060045  0.534052  0.492859  0.123659  0.419660 -0.008768 -0.074727
# 10 -0.039824 -0.008789 -0.081008 -0.022672  0.055650 -0.192046  0.513048
# 11 -0.695588  0.506826 -0.324411 -0.279961 -0.139980  0.074547  0.008174
# ...

# %% [markdown]
# ## 6. Sort eigen vectors in descending order

# %%
# Sort eigen values and corresponding eigen vectors in descending order
idx = eig_val.argsort()[::-1]
eig_vec = eig_vec[:,idx]
eig_val = eig_val[idx]
print("Sorted Eigen vectors ", eig_vec.shape)
print("Sorted Eigen values ", eig_val.shape, "\n")
# Out:
# Sorted Eigen vectors  (14, 14)
# Sorted Eigen values  (14,)

# %%
eig_val_pd = pd.DataFrame(eig_val)
eig_val_pd
# Out:
#            0
# 0   0.318652
# 1   0.230506
# 2   0.136693
# 3   0.089117
# 4   0.073741
# 5   0.065778
# 6   0.046077
# 7   0.044448
# 8   0.035193
# 9   0.026463
# 10  0.018428
# 11  0.014929
# 12  0.012303
# 13  0.004895

# %%
eig_vec_pd = pd.DataFrame(eig_vec)
eig_vec_pd
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.194196 -0.278340 -0.363651  0.167952  0.588539  0.000301  0.242356
# 1  -0.064367 -0.183941 -0.119349 -0.117707 -0.405482 -0.330462 -0.103637
# 2  -0.015154 -0.106519  0.285048 -0.244867 -0.011624 -0.609762  0.109662
# 3  -0.310017 -0.098611  0.286744  0.149338 -0.341622  0.238236  0.254383
# 4  -0.253655 -0.105037  0.253145  0.165013  0.199158 -0.119609 -0.197985
# 5   0.006819  0.218472 -0.036368  0.061543  0.065265 -0.431157  0.710570
# 6  -0.192230 -0.254291  0.129228  0.134606  0.021711 -0.078438  0.064783
# 7  -0.435900 -0.283847 -0.000141  0.374636 -0.008834 -0.078428 -0.124497
# 8  -0.034361  0.076154  0.340373  0.331116 -0.302384  0.165781  0.270832
# 9  -0.060045  0.534052  0.492859  0.123659  0.419660 -0.031648 -0.158767
# 10 -0.039824 -0.008789 -0.081008 -0.022672  0.055650  0.366914  0.369298
# 11 -0.695588  0.506826 -0.324411 -0.279961 -0.139980  0.000844 -0.041788
# ...

# %% [markdown]
# ## 7. Compute explained variance and select N components

# %%
# Get explained variance
sum_eig_val = np.sum(eig_val)
explained_variance = eig_val/ sum_eig_val
print("Explained variance ", explained_variance)
cumulative_variance = np.cumsum(explained_variance)
print("Cumulative variance ", cumulative_variance)

# Plot explained variance
plt.plot(range(1,15), cumulative_variance)
plt.title("Explained variance vs number of components")
plt.xlabel("Number of components")
plt.ylabel("Explained variance")
plt.xticks(range(1,15))
plt.vlines(x=3, ymin=0.28, ymax=0.613, colors='r',linestyles='dashed')
plt.show()

## We will 2 components
n_comp = 3
eig_vec = eig_vec[:,:n_comp]
print(eig_vec.shape)
# Out:
# Explained variance  [0.28521822 0.20632038 0.12235051 0.07976641 0.06600432 0.05887605
#  0.0412421  0.03978436 0.03150072 0.02368614 0.01649444 0.01336238
#  0.01101229 0.00438168]
# Cumulative variance  [0.28521822 0.4915386  0.61388912 0.69365552 0.75965985 0.81853589
#  0.85977799 0.89956235 0.93106307 0.95474921 0.97124365 0.98460602
#  0.99561832 1.        ]
# (14, 3)

# %%
eig_vec
# Out:
# array([[-1.94195517e-01, -2.78340167e-01, -3.63650886e-01],
#        [-6.43673215e-02, -1.83940588e-01, -1.19349381e-01],
#        [-1.51542764e-02, -1.06518519e-01,  2.85047509e-01],
#        [-3.10017111e-01, -9.86107084e-02,  2.86744104e-01],
#        [-2.53654793e-01, -1.05036594e-01,  2.53145262e-01],
#        [ 6.81923346e-03,  2.18471531e-01, -3.63681893e-02],
#        [-1.92230000e-01, -2.54291024e-01,  1.29227515e-01],
#        [-4.35899965e-01, -2.83847423e-01, -1.41322571e-04],
#        [-3.43605352e-02,  7.61539372e-02,  3.40373205e-01],
#        [-6.00452218e-02,  5.34052036e-01,  4.92858538e-01],
#        [-3.98241645e-02, -8.78880903e-03, -8.10081787e-02],
#        [-6.95587581e-01,  5.06826390e-01, -3.24411113e-01],
#        [-2.37763096e-01, -1.85907459e-01,  1.24960734e-01],
#        [-1.53983338e-01, -2.84787199e-01,  3.48928386e-01]])

# %% [markdown]
# ## 8. Project data

# %%
# Take transpose of eigen vectors with data
pca_data = mean_data.dot(eig_vec)
print("Transformed data ", pca_data.shape)
# Out:
# Transformed data  (36, 3)

# %%
pca_data
# Out:
#            0         1         2
# 0  -0.445555 -0.159812 -0.237873
# 1  -0.846201 -0.219934  0.074262
# 2   0.018569  0.202927 -0.362871
# 3   0.679677 -0.406127  0.279080
# 4  -0.719148 -0.004006  0.466210
# 5  -0.259556  0.428284  0.255571
# 6  -0.885069 -0.401978 -0.017728
# 7   0.140006 -0.620693 -0.282818
# 8  -0.023171  0.614028 -0.057718
# 9   0.106812  0.410103 -0.458914
# 10  0.779630  0.040405  0.230372
# 11 -0.468724 -0.379106 -0.511288
# 12 -0.107680 -0.095337 -0.860693
# 13 -0.734840  0.199004  0.336862
# 14  0.771403 -0.206652  0.228341
# 15  0.784956  0.144417  0.214406
# 16 -0.082178  0.581663  0.126794
# 17  0.312006 -0.569477  0.456339
# 18 -0.010671  0.781498 -0.373921
# 19 -0.849745 -0.522744  0.238233
# 20  0.016501  0.605128  0.125976
# 21 -0.753600  0.075652  0.255010
# 22  1.111938  0.413325 -0.000764
# 23 -0.513133 -0.322752 -0.468978
# 24  0.563749 -0.359395  0.286230
# 25  0.388033 -0.138718  0.766600
# 26 -0.090194  0.626708  0.395448
# ...

# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing
import sklearn.cluster as cluster
import sklearn.metrics as metrics

# %%
elbow_data = mean_data.dot(eig_vec)
elbow_data
# Out:
#            0         1         2
# 0  -0.445555 -0.159812 -0.237873
# 1  -0.846201 -0.219934  0.074262
# 2   0.018569  0.202927 -0.362871
# 3   0.679677 -0.406127  0.279080
# 4  -0.719148 -0.004006  0.466210
# 5  -0.259556  0.428284  0.255571
# 6  -0.885069 -0.401978 -0.017728
# 7   0.140006 -0.620693 -0.282818
# 8  -0.023171  0.614028 -0.057718
# 9   0.106812  0.410103 -0.458914
# 10  0.779630  0.040405  0.230372
# 11 -0.468724 -0.379106 -0.511288
# 12 -0.107680 -0.095337 -0.860693
# 13 -0.734840  0.199004  0.336862
# 14  0.771403 -0.206652  0.228341
# 15  0.784956  0.144417  0.214406
# 16 -0.082178  0.581663  0.126794
# 17  0.312006 -0.569477  0.456339
# 18 -0.010671  0.781498 -0.373921
# 19 -0.849745 -0.522744  0.238233
# 20  0.016501  0.605128  0.125976
# 21 -0.753600  0.075652  0.255010
# 22  1.111938  0.413325 -0.000764
# 23 -0.513133 -0.322752 -0.468978
# 24  0.563749 -0.359395  0.286230
# 25  0.388033 -0.138718  0.766600
# 26 -0.090194  0.626708  0.395448
# ...

# %%
wcss = []
for i in range(1,11):
   model = KMeans(n_clusters = i, init = "k-means++")
   model.fit(elbow_data)
   wcss.append(model.inertia_)
plt.figure(figsize=(10,10))
plt.plot(range(1,11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
model = KMeans(n_clusters = 3, init = "k-means++")
label = model.fit_predict(pca_data)
print(label)
# Out:
# [1 1 0 2 1 0 1 1 0 0 2 1 1 1 2 2 0 2 0 1 0 1 2 1 2 2 0 1 0 0 1 2 2 2 1 0]

# %%
from sklearn import metrics
silhouette_vals = metrics.silhouette_samples(pca_data,label)
silhouette_vals
# Out:
# array([ 0.34969597,  0.4167093 ,  0.30177177,  0.59427369,  0.17185462,
#         0.46289991,  0.46213647, -0.04899652,  0.64342638,  0.4441761 ,
#         0.50489886,  0.41265383,  0.06126085,  0.02733932,  0.59918073,
#         0.4330977 ,  0.6314531 ,  0.33350649,  0.55305024,  0.43126195,
#         0.63281675,  0.18375934,  0.27456642,  0.41947077,  0.56128977,
#         0.28235643,  0.54530026,  0.19925599,  0.54067222,  0.55628564,
#         0.2740435 ,  0.52540936,  0.37060773,  0.52641286,  0.05172815,
#         0.14232769])

# %%
ss=np.mean(silhouette_vals)
ss
# Out:
# 0.38533204538847066

# %%
metrics.silhouette_score(pca_data, model.labels_, metric='euclidean')
# Out:
# 0.38533204538847066

# %%
model.n_iter_
# Out:
# 3

# %%
wcss = []
wcss.append(model.inertia_)
wcss
# Out:
# [9.771424210077186]

# %%
centers = np.array(model.cluster_centers_)
centers
# Out:
# array([[-0.06487097,  0.55359861, -0.01044676],
#        [-0.50152796, -0.28165835, -0.09634281],
#        [ 0.70317928, -0.19512436,  0.13306489]])

# %%
p=pca_data
p['Hasil_PCA']=label
p=p.values
p
# Out:
# array([[-4.45555471e-01, -1.59812432e-01, -2.37872501e-01,
#          1.00000000e+00],
#        [-8.46201127e-01, -2.19934276e-01,  7.42623361e-02,
#          1.00000000e+00],
#        [ 1.85691773e-02,  2.02926563e-01, -3.62870517e-01,
#          0.00000000e+00],
#        [ 6.79677059e-01, -4.06127433e-01,  2.79079776e-01,
#          2.00000000e+00],
#        [-7.19148039e-01, -4.00574341e-03,  4.66210375e-01,
#          1.00000000e+00],
#        [-2.59555662e-01,  4.28283806e-01,  2.55570526e-01,
#          0.00000000e+00],
#        [-8.85068671e-01, -4.01978113e-01, -1.77275668e-02,
#          1.00000000e+00],
#        [ 1.40006324e-01, -6.20693381e-01, -2.82817826e-01,
#          1.00000000e+00],
#        [-2.31714881e-02,  6.14027886e-01, -5.77177909e-02,
#          0.00000000e+00],
#        [ 1.06812283e-01,  4.10102881e-01, -4.58914408e-01,
#          0.00000000e+00],
#        [ 7.79630010e-01,  4.04045998e-02,  2.30371935e-01,
#          2.00000000e+00],
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Upload File
from google.colab import files
# !rm Dataset_Puskesmas.xlsx
files.upload()
# Out:
#      <input type="file" id="files-f29b4147-8f88-4f77-91c7-f8f9faa44652" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f29b4147-8f88-4f77-91c7-f8f9faa44652">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Dataset = pd.read_excel('Dataset_Puskesmas.xlsx')
Dataset
# Out:
#        Nama_Puskesmas  Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0         Bandarharjo                   10                 0
# 1          Banget Ayu                    8                 1
# 2            Bugangan                    2                 1
# 3            Bulu Lor                    0                 0
# 4           Candilama                    0                 0
# 5          Gayam Sari                    6                 0
# 6               Genuk                    0                 0
# 7         Gunung Pati                    8                 0
# 8           Halmahera                   13                 0
# 9               Kagok                    0                 0
# 10       Karang Anyar                    4                 0
# 11         Karang Ayu                    2                 0
# 12        Karang Doro                   10                 0
# 13      Karang Malang                   10                 2
# ...

# %%
p = pd.DataFrame(p)
p
# Out:
#            0         1         2    3
# 0  -0.445555 -0.159812 -0.237873  1.0
# 1  -0.846201 -0.219934  0.074262  1.0
# 2   0.018569  0.202927 -0.362871  0.0
# 3   0.679677 -0.406127  0.279080  2.0
# 4  -0.719148 -0.004006  0.466210  1.0
# 5  -0.259556  0.428284  0.255571  0.0
# 6  -0.885069 -0.401978 -0.017728  1.0
# 7   0.140006 -0.620693 -0.282818  1.0
# 8  -0.023171  0.614028 -0.057718  0.0
# 9   0.106812  0.410103 -0.458914  0.0
# 10  0.779630  0.040405  0.230372  2.0
# 11 -0.468724 -0.379106 -0.511288  1.0
# 12 -0.107680 -0.095337 -0.860693  1.0
# 13 -0.734840  0.199004  0.336862  1.0
# 14  0.771403 -0.206652  0.228341  2.0
# 15  0.784956  0.144417  0.214406  2.0
# 16 -0.082178  0.581663  0.126794  0.0
# 17  0.312006 -0.569477  0.456339  2.0
# 18 -0.010671  0.781498 -0.373921  0.0
# 19 -0.849745 -0.522744  0.238233  1.0
# 20  0.016501  0.605128  0.125976  0.0
# 21 -0.753600  0.075652  0.255010  1.0
# 22  1.111938  0.413325 -0.000764  2.0
# 23 -0.513133 -0.322752 -0.468978  1.0
# ...

# %%
Dataset = Dataset[(Dataset.Jumlah_Dokter_Umum > 0) & (Dataset.Jumlah_Perawat > 0) & (Dataset.Jumlah_Bidan > 0)]
Dataset
# Out:
#        Nama_Puskesmas  Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0         Bandarharjo                   10                 0
# 1          Banget Ayu                    8                 1
# 2            Bugangan                    2                 1
# 4           Candilama                    0                 0
# 5          Gayam Sari                    6                 0
# 6               Genuk                    0                 0
# 7         Gunung Pati                    8                 0
# 8           Halmahera                   13                 0
# 9               Kagok                    0                 0
# 10       Karang Anyar                    4                 0
# 11         Karang Ayu                    2                 0
# 12        Karang Doro                   10                 0
# 13      Karang Malang                   10                 2
# 14       Kedung Mundu                    0                 1
# ...

# %%
Dataset = Dataset.reset_index()
Dataset
# Out:
#     index     Nama_Puskesmas  Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0       0        Bandarharjo                   10                 0
# 1       1         Banget Ayu                    8                 1
# 2       2           Bugangan                    2                 1
# 3       4          Candilama                    0                 0
# 4       5         Gayam Sari                    6                 0
# 5       6              Genuk                    0                 0
# 6       7        Gunung Pati                    8                 0
# 7       8          Halmahera                   13                 0
# 8       9              Kagok                    0                 0
# 9      10       Karang Anyar                    4                 0
# 10     11         Karang Ayu                    2                 0
# 11     12        Karang Doro                   10                 0
# 12     13      Karang Malang                   10                 2
# ...

# %%
Dataset = Dataset.drop('index', axis=1)
Dataset
# Out:
#        Nama_Puskesmas  Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0         Bandarharjo                   10                 0
# 1          Banget Ayu                    8                 1
# 2            Bugangan                    2                 1
# 3           Candilama                    0                 0
# 4          Gayam Sari                    6                 0
# 5               Genuk                    0                 0
# 6         Gunung Pati                    8                 0
# 7           Halmahera                   13                 0
# 8               Kagok                    0                 0
# 9        Karang Anyar                    4                 0
# 10         Karang Ayu                    2                 0
# 11        Karang Doro                   10                 0
# 12      Karang Malang                   10                 2
# 13       Kedung Mundu                    0                 1
# ...

# %%
p[3].replace({1: 2, 2: 3, 0: 1}, inplace=True)
p
# Out:
#            0         1         2    3
# 0  -0.445555 -0.159812 -0.237873  2.0
# 1  -0.846201 -0.219934  0.074262  2.0
# 2   0.018569  0.202927 -0.362871  1.0
# 3   0.679677 -0.406127  0.279080  3.0
# 4  -0.719148 -0.004006  0.466210  2.0
# 5  -0.259556  0.428284  0.255571  1.0
# 6  -0.885069 -0.401978 -0.017728  2.0
# 7   0.140006 -0.620693 -0.282818  2.0
# 8  -0.023171  0.614028 -0.057718  1.0
# 9   0.106812  0.410103 -0.458914  1.0
# 10  0.779630  0.040405  0.230372  3.0
# 11 -0.468724 -0.379106 -0.511288  2.0
# 12 -0.107680 -0.095337 -0.860693  2.0
# 13 -0.734840  0.199004  0.336862  2.0
# 14  0.771403 -0.206652  0.228341  3.0
# 15  0.784956  0.144417  0.214406  3.0
# 16 -0.082178  0.581663  0.126794  1.0
# 17  0.312006 -0.569477  0.456339  3.0
# 18 -0.010671  0.781498 -0.373921  1.0
# 19 -0.849745 -0.522744  0.238233  2.0
# 20  0.016501  0.605128  0.125976  1.0
# 21 -0.753600  0.075652  0.255010  2.0
# 22  1.111938  0.413325 -0.000764  3.0
# 23 -0.513133 -0.322752 -0.468978  2.0
# ...

# %%
viz = Dataset
viz['hasil_pca'] = p[3]
viz
# Out:
#        Nama_Puskesmas  Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0         Bandarharjo                   10                 0
# 1          Banget Ayu                    8                 1
# 2            Bugangan                    2                 1
# 3           Candilama                    0                 0
# 4          Gayam Sari                    6                 0
# 5               Genuk                    0                 0
# 6         Gunung Pati                    8                 0
# 7           Halmahera                   13                 0
# 8               Kagok                    0                 0
# 9        Karang Anyar                    4                 0
# 10         Karang Ayu                    2                 0
# 11        Karang Doro                   10                 0
# 12      Karang Malang                   10                 2
# 13       Kedung Mundu                    0                 1
# ...

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Tempat_Tidur'], viz['Jumlah_Ambulance'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Tempat Tidur')
plt.ylabel('Jumlah Ambulan')
plt.title('Plotting Tempat Tidur dan Ambulan')
plt.show()

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Puskesmas_Keliling_Roda_Empat'], viz['Jumlah_Puskesmas_Pembantu'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Puskesmas Keliling')
plt.ylabel('Jumlah Puskesmas Pembantu')
plt.title('Plotting Puskesmas Keliling dan Puskesmas Pembantu')
plt.show()

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Dokter_Umum'], viz['Jumlah_Dokter_Gigi'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Dokter Umum')
plt.ylabel('Jumlah Dokter Gigi')
plt.title('Plotting Dokter Umum dan Dokter Gigi')
plt.show()

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Perawat'], viz['Jumlah_Bidan'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Perawat')
plt.ylabel('Jumlah Bidan')
plt.title('Plotting Perawat dan Bidan')
plt.show()

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Farmasi'], viz['Jumlah_Kesehatan_Masyarakat'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Farmasi')
plt.ylabel('Jumlah Kesehatan Masyarakat')
plt.title('Plotting Farmasi dan Kesehatan Masyarakat')
plt.show()

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Kesehatan_Lingkungan'], viz['Jumlah_Tenaga_Gizi'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Kesehatan Lingkungan')
plt.ylabel('Jumlah Tenaga Gizi')
plt.title('Plotting Kesehatan Lingkungan dan Tenaga Gizi')
plt.show()

# %%
plt.figure(figsize=(10,10))
uniq = np.unique(viz['hasil_pca'])
scatter = plt.scatter(viz['Jumlah_Tenaga_Ahli_Teknologi_Laboratorium_Medik'], viz['Jumlah_Tenaga_Non_Medis'], c=viz['hasil_pca'], s=50, cmap='viridis')
plt.legend(*scatter.legend_elements(), title="Klaster")
plt.xlabel('Jumlah Ahli Teknologi Laboratorium Medik')
plt.ylabel('Jumlah Tenaga Non Medis')
plt.title('Plotting Ahli Teknologi Laboratorium Medik dan Tenaga Non Medis')
plt.show()

# %%
import plotly.express as px
fig = px.scatter_3d(p, x=0, y=1, z=2,
              color=3)
fig.update_layout(title_text='Plotting Hasil Klaster', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
MM = pd.read_excel('MM.xlsx')
MM = MM.iloc[:,1:]
MM
# Out:
#     Jumlah_Tempat_Tidur  Jumlah_Ambulance  \
# 0              0.769231          0.000000
# 1              0.615385          0.333333
# 2              0.153846          0.333333
# 3              0.000000          0.000000
# 4              0.461538          0.000000
# 5              0.000000          0.000000
# 6              0.615385          0.000000
# 7              1.000000          0.000000
# 8              0.000000          0.000000
# 9              0.307692          0.000000
# 10             0.153846          0.000000
# 11             0.769231          0.000000
# 12             0.769231          0.666667
# 13             0.000000          0.333333
# 14             0.076923          0.000000
# 15             0.000000          0.000000
# 16             0.307692          0.000000
# 17             0.230769          0.000000
# 18             0.461538          0.000000
# 19             0.000000          0.333333
# 20             0.153846          0.333333
# ...

# %%
model2 = KMeans(n_clusters = 3, init = "k-means++")
label2 = model2.fit_predict(MM)
print(label2)
# Out:
# [2 2 0 1 2 0 2 1 0 0 1 2 0 2 1 1 0 1 0 2 0 2 1 2 1 1 0 2 0 0 2 1 1 1 1 2]

# %%
metrics.silhouette_score(MM, model2.labels_, metric='euclidean')
# Out:
# 0.2013319611364834

# %%
wcss2 = []
wcss2.append(model2.inertia_)
wcss2
# Out:
# [24.561201075128118]

# %%
o=org_data
o['Hasil']=label2
o=o.values
o = pd.DataFrame(o)
o
# Out:
#           0         1         2     3     4    5         6    7         8   \
# 0   0.769231  0.000000  0.333333  0.25  0.75  0.0  0.538462  0.2  0.333333
# 1   0.615385  0.333333  0.333333  0.50  0.50  0.0  0.615385  1.0  0.666667
# 2   0.153846  0.333333  0.333333  0.00  0.25  0.0  0.153846  0.2  0.333333
# 3   0.000000  0.000000  0.333333  0.25  0.25  0.0  0.230769  0.1  1.000000
# 4   0.461538  0.000000  0.333333  0.75  0.75  0.0  0.384615  0.5  1.000000
# 5   0.000000  0.000000  0.000000  0.50  0.50  0.0  0.307692  0.3  1.000000
# 6   0.615385  0.000000  0.333333  0.50  1.00  0.0  0.615385  0.9  0.333333
# 7   1.000000  0.000000  0.000000  0.00  0.75  0.0  0.692308  0.7  0.666667
# 8   0.000000  0.000000  0.333333  0.25  0.50  0.0  0.230769  0.2  0.666667
# 9   0.307692  0.000000  0.333333  0.00  0.25  0.0  0.307692  0.1  0.666667
# 10  0.153846  0.000000  0.333333  0.00  0.25  0.0  0.076923  0.1  0.666667
# ...

# %%
comp = o
comp['hasil_pca'] = p[3]
comp
# Out:
#            0         1         2     3     4    5         6    7         8  \
# 0   0.769231  0.000000  0.333333  0.25  0.75  0.0  0.538462  0.2  0.333333
# 1   0.615385  0.333333  0.333333  0.50  0.50  0.0  0.615385  1.0  0.666667
# 2   0.153846  0.333333  0.333333  0.00  0.25  0.0  0.153846  0.2  0.333333
# 3   0.000000  0.000000  0.333333  0.25  0.25  0.0  0.230769  0.1  1.000000
# 4   0.461538  0.000000  0.333333  0.75  0.75  0.0  0.384615  0.5  1.000000
# 5   0.000000  0.000000  0.000000  0.50  0.50  0.0  0.307692  0.3  1.000000
# 6   0.615385  0.000000  0.333333  0.50  1.00  0.0  0.615385  0.9  0.333333
# 7   1.000000  0.000000  0.000000  0.00  0.75  0.0  0.692308  0.7  0.666667
# 8   0.000000  0.000000  0.333333  0.25  0.50  0.0  0.230769  0.2  0.666667
# 9   0.307692  0.000000  0.333333  0.00  0.25  0.0  0.307692  0.1  0.666667
# 10  0.153846  0.000000  0.333333  0.00  0.25  0.0  0.076923  0.1  0.666667
# ...

# %%
comp['hasil_pca'].replace({0: 2, 2: 0}, inplace=True)
comp[14].replace({2: 1, 1: 2}, inplace=True)
comp
# Out:
#            0         1         2     3     4    5         6    7         8  \
# 0   0.769231  0.000000  0.333333  0.25  0.75  0.0  0.538462  0.2  0.333333
# 1   0.615385  0.333333  0.333333  0.50  0.50  0.0  0.615385  1.0  0.666667
# 2   0.153846  0.333333  0.333333  0.00  0.25  0.0  0.153846  0.2  0.333333
# 3   0.000000  0.000000  0.333333  0.25  0.25  0.0  0.230769  0.1  1.000000
# 4   0.461538  0.000000  0.333333  0.75  0.75  0.0  0.384615  0.5  1.000000
# 5   0.000000  0.000000  0.000000  0.50  0.50  0.0  0.307692  0.3  1.000000
# 6   0.615385  0.000000  0.333333  0.50  1.00  0.0  0.615385  0.9  0.333333
# 7   1.000000  0.000000  0.000000  0.00  0.75  0.0  0.692308  0.7  0.666667
# 8   0.000000  0.000000  0.333333  0.25  0.50  0.0  0.230769  0.2  0.666667
# 9   0.307692  0.000000  0.333333  0.00  0.25  0.0  0.307692  0.1  0.666667
# 10  0.153846  0.000000  0.333333  0.00  0.25  0.0  0.076923  0.1  0.666667
# ...

# %%
p[3].replace({0: 2, 2: 0}, inplace=True)
p
# Out:
#            0         1         2    3
# 0  -0.445555 -0.159812 -0.237873  1.0
# 1  -0.846201 -0.219934  0.074262  1.0
# 2   0.018569  0.202927 -0.362871  0.0
# 3   0.679677 -0.406127  0.279080  2.0
# 4  -0.719148 -0.004006  0.466210  1.0
# 5  -0.259556  0.428284  0.255571  0.0
# 6  -0.885069 -0.401978 -0.017728  1.0
# 7   0.140006 -0.620693 -0.282818  1.0
# 8  -0.023171  0.614028 -0.057718  0.0
# 9   0.106812  0.410103 -0.458914  0.0
# 10  0.779630  0.040405  0.230372  2.0
# 11 -0.468724 -0.379106 -0.511288  1.0
# 12 -0.107680 -0.095337 -0.860693  1.0
# 13 -0.734840  0.199004  0.336862  1.0
# 14  0.771403 -0.206652  0.228341  2.0
# 15  0.784956  0.144417  0.214406  2.0
# 16 -0.082178  0.581663  0.126794  0.0
# 17  0.312006 -0.569477  0.456339  2.0
# 18 -0.010671  0.781498 -0.373921  0.0
# 19 -0.849745 -0.522744  0.238233  1.0
# 20  0.016501  0.605128  0.125976  0.0
# 21 -0.753600  0.075652  0.255010  1.0
# 22  1.111938  0.413325 -0.000764  2.0
# 23 -0.513133 -0.322752 -0.468978  1.0
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(p, x=0, y=1, z=2,
              color=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.decomposition import PCA
from sklearn import metrics
silhouette = []
for i in range(1,14):
  pca = PCA(i)
  data = pca.fit_transform(MM)
  model3 = KMeans(n_clusters = 3, init = "k-means++")
  label3 = model3.fit_predict(data)
  silhouette.append(metrics.silhouette_score(data, model3.labels_, metric='euclidean'))
  print('Silhouette ke',i,silhouette[i-1])
plt.figure(figsize=(10,10))
plt.plot(range(1,14), silhouette)
plt.xlabel('Total Dimension')
plt.ylabel('silhouette')
plt.show()
# Out:
# Silhouette ke 1 0.673402474560345
# Silhouette ke 2 0.5195276405080678
# Silhouette ke 3 0.38533204538847077
# Silhouette ke 4 0.3360274661512051
# Silhouette ke 5 0.2957949821268049
# Silhouette ke 6 0.2690817505847003
# Silhouette ke 7 0.2565053736488433
# Silhouette ke 8 0.2314117530233342
# Silhouette ke 9 0.22970105886190634
# Silhouette ke 10 0.21602661006770468
# Silhouette ke 11 0.21320876139025702
# Silhouette ke 12 0.2054559913057482
# Silhouette ke 13 0.20203300615316053

# %%
  pca = PCA(3)
  data = pca.fit_transform(MM)
  model4 = KMeans(n_clusters = 3, init = "k-means++")
  label4 = model4.fit_predict(data)
  print(label4)
  print(label)
# Out:
# [0 0 2 1 0 2 0 0 2 2 1 0 0 0 1 1 2 1 2 0 2 0 1 0 1 1 2 0 2 2 0 1 1 1 0 2]
# [2 2 0 1 2 0 2 1 0 0 1 2 2 2 1 1 0 1 0 2 0 2 1 2 1 1 0 2 0 0 2 1 1 1 2 0]

# %%
data = pd.DataFrame(data)
data
# Out:
#            0         1         2
# 0  -0.445555  0.159812  0.237873
# 1  -0.846201  0.219934 -0.074262
# 2   0.018569 -0.202927  0.362871
# 3   0.679677  0.406127 -0.279080
# 4  -0.719148  0.004006 -0.466210
# 5  -0.259556 -0.428284 -0.255571
# 6  -0.885069  0.401978  0.017728
# 7   0.140006  0.620693  0.282818
# 8  -0.023171 -0.614028  0.057718
# 9   0.106812 -0.410103  0.458914
# 10  0.779630 -0.040405 -0.230372
# 11 -0.468724  0.379106  0.511288
# 12 -0.107680  0.095337  0.860693
# 13 -0.734840 -0.199004 -0.336862
# 14  0.771403  0.206652 -0.228341
# 15  0.784956 -0.144417 -0.214406
# 16 -0.082178 -0.581663 -0.126794
# 17  0.312006  0.569477 -0.456339
# 18 -0.010671 -0.781498  0.373921
# 19 -0.849745  0.522744 -0.238233
# 20  0.016501 -0.605128 -0.125976
# 21 -0.753600 -0.075652 -0.255010
# 22  1.111938 -0.413325  0.000764
# 23 -0.513133  0.322752  0.468978
# 24  0.563749  0.359395 -0.286230
# 25  0.388033  0.138718 -0.766600
# 26 -0.090194 -0.626708 -0.395448
# ...

# %%
comp['hasil_pca3'] = label4
comp['hasil_pca3'].replace({0: 2, 2: 0}, inplace=True)
comp
# Out:
#            0         1         2     3     4    5         6    7         8  \
# 0   0.769231  0.000000  0.333333  0.25  0.75  0.0  0.538462  0.2  0.333333
# 1   0.615385  0.333333  0.333333  0.50  0.50  0.0  0.615385  1.0  0.666667
# 2   0.153846  0.333333  0.333333  0.00  0.25  0.0  0.153846  0.2  0.333333
# 3   0.000000  0.000000  0.333333  0.25  0.25  0.0  0.230769  0.1  1.000000
# 4   0.461538  0.000000  0.333333  0.75  0.75  0.0  0.384615  0.5  1.000000
# 5   0.000000  0.000000  0.000000  0.50  0.50  0.0  0.307692  0.3  1.000000
# 6   0.615385  0.000000  0.333333  0.50  1.00  0.0  0.615385  0.9  0.333333
# 7   1.000000  0.000000  0.000000  0.00  0.75  0.0  0.692308  0.7  0.666667
# 8   0.000000  0.000000  0.333333  0.25  0.50  0.0  0.230769  0.2  0.666667
# 9   0.307692  0.000000  0.333333  0.00  0.25  0.0  0.307692  0.1  0.666667
# 10  0.153846  0.000000  0.333333  0.00  0.25  0.0  0.076923  0.1  0.666667
# ...

# %%
comp[14].replace({1: 2, 2: 1}, inplace=True)
comp['hasil_pca'].replace({1: 2, 2: 1}, inplace=True)
comp['hasil_pca3'].replace({1: 2, 2: 1}, inplace=True)

# %%
comp[14].replace({1: 2, 2: 1}, inplace=True)
comp
# Out:
#            0         1         2     3     4    5         6    7         8  \
# 0   0.769231  0.000000  0.333333  0.25  0.75  0.0  0.538462  0.2  0.333333
# 1   0.615385  0.333333  0.333333  0.50  0.50  0.0  0.615385  1.0  0.666667
# 2   0.153846  0.333333  0.333333  0.00  0.25  0.0  0.153846  0.2  0.333333
# 3   0.000000  0.000000  0.333333  0.25  0.25  0.0  0.230769  0.1  1.000000
# 4   0.461538  0.000000  0.333333  0.75  0.75  0.0  0.384615  0.5  1.000000
# 5   0.000000  0.000000  0.000000  0.50  0.50  0.0  0.307692  0.3  1.000000
# 6   0.615385  0.000000  0.333333  0.50  1.00  0.0  0.615385  0.9  0.333333
# 7   1.000000  0.000000  0.000000  0.00  0.75  0.0  0.692308  0.7  0.666667
# 8   0.000000  0.000000  0.333333  0.25  0.50  0.0  0.230769  0.2  0.666667
# 9   0.307692  0.000000  0.333333  0.00  0.25  0.0  0.307692  0.1  0.666667
# 10  0.153846  0.000000  0.333333  0.00  0.25  0.0  0.076923  0.1  0.666667
# ...

# %%
data['hasil_pca3'] = comp['hasil_pca3']
data
# Out:
#            0         1         2  hasil_pca3
# 0  -0.445555  0.159812  0.237873           1
# 1  -0.846201  0.219934 -0.074262           1
# 2   0.018569 -0.202927  0.362871           0
# 3   0.679677  0.406127 -0.279080           2
# 4  -0.719148  0.004006 -0.466210           1
# 5  -0.259556 -0.428284 -0.255571           0
# 6  -0.885069  0.401978  0.017728           1
# 7   0.140006  0.620693  0.282818           1
# 8  -0.023171 -0.614028  0.057718           0
# 9   0.106812 -0.410103  0.458914           0
# 10  0.779630 -0.040405 -0.230372           2
# 11 -0.468724  0.379106  0.511288           1
# 12 -0.107680  0.095337  0.860693           1
# 13 -0.734840 -0.199004 -0.336862           1
# 14  0.771403  0.206652 -0.228341           2
# 15  0.784956 -0.144417 -0.214406           2
# 16 -0.082178 -0.581663 -0.126794           0
# 17  0.312006  0.569477 -0.456339           2
# 18 -0.010671 -0.781498  0.373921           0
# 19 -0.849745  0.522744 -0.238233           1
# ...

# %%
import plotly.express as px
fig = px.scatter_3d(data, x=0, y=1, z=2,
              color='hasil_pca3')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
